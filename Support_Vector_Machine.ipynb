# %% [markdown]
# # HARDCODED SUPPORT VECTOR MACHINE

# %% [markdown]
# #### LOAD DATASET

# %%
## Importing Libraries
import pandas as pd
import numpy as np
import matplotlib. pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
## Loading the dataset
from sklearn.datasets import load_iris
iris = load_iris()

# %%
## Displaying Input Variables
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['flower_name'] =df.target.apply(lambda x: iris.target_names[x])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
df0 = df[:50]
df1 = df[50:100]
df2=df[100:150]

# %%
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.scatter(df0['sepal length (cm)'], df0['sepal width (cm)'],color="green",marker='+')
plt.scatter(df1['sepal length (cm)'], df1['sepal width (cm)'],color="blue",marker='.')
plt.scatter(df2['sepal length (cm)'], df2['sepal width (cm)'],color="red",marker='*')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# Load the Iris dataset
iris = sns.load_dataset("iris")

# Create a 3D plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(iris['sepal_length'], iris['sepal_width'], iris['petal_length'], c=iris['species'].astype('category').cat.codes, cmap='viridis', s=50)

# Set labels
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Petal Length')

# Show the plot
plt.show()

# %%
import plotly.express as px

fig = px.scatter_3d(iris, x='sepal_length', y='sepal_width', z='petal_length', color='species')
fig.update_layout(scene=dict(aspectmode="data"))
# Save the plot as an interactive HTML file
fig.write_html("iris_3d_plot1.html")

# %%
import ipyvolume as ipv
import seaborn as sns

# Load the Iris dataset
iris = sns.load_dataset("iris")

# Create a 3D scatter plot
fig = ipv.figure()
scatter = ipv.scatter(iris['sepal_length'], iris['sepal_width'], iris['petal_length'], color=iris['species'].astype('category').cat.codes, size=2)

# Set labels
ipv.xlabel('Sepal Length')
ipv.ylabel('Sepal Width')
ipv.zlabel('Petal Length')

# Show the plot
ipv.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\DELL\Documents\Amrita\Codes\Sem_5_Codes\Machine_Learning\Support_Vector_Machine.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DELL/Documents/Amrita/Codes/Sem_5_Codes/Machine_Learning/Support_Vector_Machine.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> import ipyvolume as ipv
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/Documents/Amrita/Codes/Sem_5_Codes/Machine_Learning/Support_Vector_Machine.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/Documents/Amrita/Codes/Sem_5_Codes/Machine_Learning/Support_Vector_Machine.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> # Load the Iris dataset
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipyvolume\__init__.py:8
# ...
